# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("public_health.csv")

# %%
data
# Out:
#                        Country Name      1995      1996      1997      1998  \
# 0                        Arab World  2.004868  2.014602  2.071309  2.177712
# 1            Caribbean small states  2.801518  2.856684  2.997157  2.989451
# 2    Central Europe and the Baltics  4.678528  4.753209  4.604574  4.499988
# 3        Early-demographic dividend  2.203164  2.156632  2.227311  2.364100
# 4               East Asia & Pacific  4.429090  4.203152  4.244351  4.453984
# ..                              ...       ...       ...       ...       ...
# 219                         Vanuatu  2.139305  1.749747  2.296830  3.038570
# 220                   Venezuela, RB  1.803152  1.482415  1.387316  1.466016
# 221                         Vietnam  1.757863  1.632232  1.604611  1.731438
# 222                     Yemen, Rep.  1.358740  1.644501  1.898410  2.324038
# 223                          Zambia  2.152489  2.484678  2.585239  3.133965
#
# ...

# %%
#data[data["Country Name"] == "Marshall Islands"]
data1 = pd.DataFrame(data["Country Name"])

# %%
type(data)
data
# Out:
#                        Country Name      1995      1996      1997      1998  \
# 0                        Arab World  2.004868  2.014602  2.071309  2.177712
# 1            Caribbean small states  2.801518  2.856684  2.997157  2.989451
# 2    Central Europe and the Baltics  4.678528  4.753209  4.604574  4.499988
# 3        Early-demographic dividend  2.203164  2.156632  2.227311  2.364100
# 4               East Asia & Pacific  4.429090  4.203152  4.244351  4.453984
# ..                              ...       ...       ...       ...       ...
# 219                         Vanuatu  2.139305  1.749747  2.296830  3.038570
# 220                   Venezuela, RB  1.803152  1.482415  1.387316  1.466016
# 221                         Vietnam  1.757863  1.632232  1.604611  1.731438
# 222                     Yemen, Rep.  1.358740  1.644501  1.898410  2.324038
# 223                          Zambia  2.152489  2.484678  2.585239  3.133965
#
# ...

# %%
data2 = data.drop("Country Name",axis = 1)

# %%
data2
# Out:
#          1995      1996      1997      1998      1999      2000      2001  \
# 0    2.004868  2.014602  2.071309  2.177712  2.331000  2.333596  2.588751
# 1    2.801518  2.856684  2.997157  2.989451  2.767858  2.826752  2.679969
# 2    4.678528  4.753209  4.604574  4.499988  4.679082  4.539711  4.666272
# 3    2.203164  2.156632  2.227311  2.364100  2.454394  2.450555  2.527081
# 4    4.429090  4.203152  4.244351  4.453984  4.626920  4.688849  4.684790
# ..        ...       ...       ...       ...       ...       ...       ...
# 219  2.139305  1.749747  2.296830  3.038570  2.639953  2.736929  2.788550
# 220  1.803152  1.482415  1.387316  1.466016  1.833422  2.163059  2.340757
# 221  1.757863  1.632232  1.604611  1.731438  1.717060  1.513863  1.627561
# 222  1.358740  1.644501  1.898410  2.324038  2.127391  2.235286  2.294181
# 223  2.152489  2.484678  2.585239  3.133965  3.403697  3.719900  3.526559
#
#          2002      2003      2004      2005      2006      2007      2008  \
# ...

# %%
data3 = pd.DataFrame(data2)


row_means = data3.mean(axis=1)


data4 = pd.DataFrame(row_means)

print(data4)
# Out:
#             0
# 0    2.395097
# 1    2.947091
# 2    4.893770
# 3    2.419608
# 4    4.573320
# ..        ...
# 219  3.113893
# 220  1.930827
# 221  2.185572
# 222  1.720078
# 223  2.920520
#
# [224 rows x 1 columns]

# %%
data5 = pd.concat([data1,data4],axis=1)

# %%
data5.columns = ["Country Name","Health Mean"]

# %%
data5 = data5.sort_values("Health Mean",ascending=False)

# %%
data5
# Out:
#               Country Name  Health Mean
# 143       Marshall Islands    16.291729
# 211                 Tuvalu    14.559207
# 156                  Nauru    11.046924
# 147  Micronesia, Fed. Sts.     9.897481
# 125               Kiribati     8.943906
# ..                     ...          ...
# 52              Bangladesh     0.986877
# 115              Indonesia     0.921120
# 77        Congo, Dem. Rep.     0.847658
# 165               Pakistan     0.758448
# 154                Myanmar     0.349996
#
# [224 rows x 2 columns]
